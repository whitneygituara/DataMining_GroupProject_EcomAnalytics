# %%
import pandas as pd
import numpy as np
import random as rnd

#The clean dataset
data = pd.read_excel(r"C:\Users\Admin\OneDrive\Documents\USIU\Datawarehousing\Groupwork\data\sales_and_customer_insights.xlsx")
print(data.head())

# View basic info
print("\n🔹 Dataset Info:")
print(data.info())

print("\n🔹 First 5 Rows:")
print(data.head())

print("\n🔹 Missing Values Count:")
print(data.isnull().sum())

print("\n🔹 Duplicate Rows:", data.duplicated().sum())

print("\n🔹 Summary Statistics:")
print(data.describe(include='all'))

# --- Step 3: Check for negative or zero quantities and prices ---
negative_qty = data[data['Quantity'] <= 0]
negative_price = data[data['UnitPrice'] <= 0]

print(f"\n🔹 Rows with non-positive quantities: {len(negative_qty)}")
print(f"🔹 Rows with non-positive unit prices: {len(negative_price)}")

# --- Step 4: Check country name inconsistencies ---
print("\n🔹 Unique countries:\n", data['Country'].unique())

# --- Step 5: Quick check for outliers using describe() ---
print("\n🔹 Summary statistics for numeric columns:\n", data.describe())
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
#
# 🔹 Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ...

# %% [markdown]
# # data mining - Act of extracting useful information information from large databases
# ## data mining techniques
# # 1. Classification
# It finds rules that partition data into groups. It requires a training dataset that has lables provided.
# It then classifies the unlabled records based on knowledge from training datasets.
# eg.
# decision tree
# neural networks
# genetic algorithims
# # 2. clustering
# This works by grouping data such that data within a cluster have high similarity and data outside a cluster are dissimilar.
# eg.
# K-Means
# DBSCAN
# OPTILS
# STING
# # 3. association rule
# It is used to find intresting relations between variables in large databases.
# It aims to discover all the rules that have support and confidence greater than or equal to minimum support
# eg.
# Apriori
# AprioriTid
# Apriori hybrid
# Tertius algorithims
# # 4. neural networks
# It involves developing mathematical structures with the ability to learn.
# It allows for the extraction of meaningful and useful patterns and trends from complex data.
# # 5. Support vector machines
# It maps input data to a higher dimentional feature space, then findsa linear seperatorin the space that best discriminates
# between classes
#
#
# ## Technique we are using - Association Rule Mining (Apriori, FP-Growth, etc.)
# ## Why Association Rule Mining Is Best for our Context
#
# Our dataset contains transaction-level records—exactly what association rule algorithms are designed for.
#
# # It uncovers:
#
# Which products are frequently bought together (market basket analysis).
#
# Cross-sell and up-sell recommendations.
#
# Product bundling insights.
#
# # It is widely used in retail analytics because it directly supports:
#
# Recommendation engines.
#
# Product placement.
#
# Promotion optimization.
#
# Requires no target variable, making it perfect for your transactional data.
